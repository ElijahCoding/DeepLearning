# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
series = np.sin(0.1 * np.arange(200)) + np.random.randn(200) * 0.1

# %%
plt.plot(series)
plt.show()

# %%
### build the dataset
# let's see if we can use T past values to predict the next value

T = 10
X = []
Y = []

for t in range(len(series) - T):
    x = series[t:t+T]
    X.append(x)
    y = series[t + T]
    Y.append(y)

X = np.array(X).reshape(-1, T)
Y = np.array(Y)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (190, 10) Y.shape (190,)

# %%
### try autoregressive linear model

# %%
i = Input(shape=(T,))
x = Dense(1)(i)

model = Model(i, x)

# %%
model.compile(optimizer=Adam(lr=0.1), loss='mse')

# %%
r = model.fit(
  X[:-N//2], Y[:-N//2],
  epochs=80,
  validation_data=(X[-N//2:], Y[-N//2:]),
)
# Out:
# Train on 95 samples, validate on 95 samples
# Epoch 1/80
# 95/95 [==============================] - 0s 5ms/sample - loss: 0.1880 - val_loss: 0.0420
# Epoch 2/80
# 95/95 [==============================] - 0s 206us/sample - loss: 0.0920 - val_loss: 0.0604
# Epoch 3/80
# 95/95 [==============================] - 0s 223us/sample - loss: 0.0446 - val_loss: 0.0616
# Epoch 4/80
# 95/95 [==============================] - 0s 235us/sample - loss: 0.0665 - val_loss: 0.0329
# Epoch 5/80
# 95/95 [==============================] - 0s 242us/sample - loss: 0.0441 - val_loss: 0.0498
# Epoch 6/80
# 95/95 [==============================] - 0s 252us/sample - loss: 0.0420 - val_loss: 0.0457
# Epoch 7/80
# 95/95 [==============================] - 0s 237us/sample - loss: 0.0450 - val_loss: 0.0284
# Epoch 8/80
# 95/95 [==============================] - 0s 234us/sample - loss: 0.0349 - val_loss: 0.0374
# Epoch 9/80
# 95/95 [==============================] - 0s 211us/sample - loss: 0.0345 - val_loss: 0.0291
# Epoch 10/80
# 95/95 [==============================] - 0s 216us/sample - loss: 0.0310 - val_loss: 0.0246
# Epoch 11/80
# 95/95 [==============================] - 0s 228us/sample - loss: 0.0309 - val_loss: 0.0279
# Epoch 12/80
# 95/95 [==============================] - 0s 215us/sample - loss: 0.0261 - val_loss: 0.0254
# Epoch 13/80
# 95/95 [==============================] - 0s 210us/sample - loss: 0.0263 - val_loss: 0.0225
# Epoch 14/80
# 95/95 [==============================] - 0s 216us/sample - loss: 0.0235 - val_loss: 0.0231
# Epoch 15/80
# 95/95 [==============================] - 0s 224us/sample - loss: 0.0231 - val_loss: 0.0222
# Epoch 16/80
# 95/95 [==============================] - 0s 228us/sample - loss: 0.0220 - val_loss: 0.0219
# Epoch 17/80
# 95/95 [==============================] - 0s 224us/sample - loss: 0.0208 - val_loss: 0.0210
# Epoch 18/80
# 95/95 [==============================] - 0s 242us/sample - loss: 0.0202 - val_loss: 0.0208
# Epoch 19/80
# 95/95 [==============================] - 0s 228us/sample - loss: 0.0200 - val_loss: 0.0205
# Epoch 20/80
# 95/95 [==============================] - 0s 225us/sample - loss: 0.0195 - val_loss: 0.0198
# Epoch 21/80
# 95/95 [==============================] - 0s 243us/sample - loss: 0.0190 - val_loss: 0.0194
# Epoch 22/80
# 95/95 [==============================] - 0s 240us/sample - loss: 0.0192 - val_loss: 0.0197
# Epoch 23/80
# 95/95 [==============================] - 0s 220us/sample - loss: 0.0181 - val_loss: 0.0191
# Epoch 24/80
# 95/95 [==============================] - 0s 254us/sample - loss: 0.0177 - val_loss: 0.0186
# Epoch 25/80
# 95/95 [==============================] - 0s 230us/sample - loss: 0.0169 - val_loss: 0.0184
# Epoch 26/80
# 95/95 [==============================] - 0s 217us/sample - loss: 0.0168 - val_loss: 0.0186
# Epoch
# 95/95 [==============================] - 0s 214us/sample - loss: 0.0145 - val_loss: 0.0202
# Epoch 60/80
# 95/95 [==============================] - 0s 203us/sample - loss: 0.0160 - val_loss: 0.0182
# Epoch 61/80
# 95/95 [==============================] - 0s 218us/sample - loss: 0.0179 - val_loss: 0.0206
# Epoch 62/80
# 95/95 [==============================] - 0s 233us/sample - loss: 0.0185 - val_loss: 0.0210
# Epoch 63/80
# 95/95 [==============================] - 0s 228us/sample - loss: 0.0209 - val_loss: 0.0174
# Epoch 64/80
# 95/95 [==============================] - 0s 206us/sample - loss: 0.0211 - val_loss: 0.0168
# Epoch 65/80
# 95/95 [==============================] - 0s 206us/sample - loss: 0.0181 - val_loss: 0.0169
# Epoch 66/80
# 95/95 [==============================] - 0s 262us/sample - loss: 0.0190 - val_loss: 0.0169
# Epoch 67/80
# 95/95 [==============================] - 0s 201us/sample - loss: 0.0150 - val_loss: 0.0166
# Epoch 68/80
# 95/95 [==============================] - 0s 214us/sample - loss: 0.0149 - val_loss: 0.0162
# Epoch 69/80
# 95/95 [==============================] - 0s 238us/sample - loss: 0.0131 - val_loss: 0.0162
# Epoch 70/80
# 95/95 [==============================] - 0s 287us/sample - loss: 0.0130 - val_loss: 0.0160
# Epoch 71/80
# 95/95 [==============================] - 0s 350us/sample - loss: 0.0136 - val_loss: 0.0164
# Epoch 72/80
# 95/95 [==============================] - 0s 352us/sample - loss: 0.0147 - val_loss: 0.0177
# Epoch 73/80
# 95/95 [==============================] - 0s 282us/sample - loss: 0.0192 - val_loss: 0.0198
# Epoch 74/80
# 95/95 [==============================] - 0s 352us/sample - loss: 0.0189 - val_loss: 0.0174
# Epoch 75/80
# 95/95 [==============================] - 0s 277us/sample - loss: 0.0183 - val_loss: 0.0181
# Epoch 76/80
# 95/95 [==============================] - 0s 259us/sample - loss: 0.0165 - val_loss: 0.0165
# Epoch 77/80
# 95/95 [==============================] - 0s 281us/sample - loss: 0.0135 - val_loss: 0.0163
# Epoch 78/80
# 95/95 [==============================] - 0s 278us/sample - loss: 0.0136 - val_loss: 0.0163
# Epoch 79/80
# 95/95 [==============================] - 0s 261us/sample - loss: 0.0137 - val_loss: 0.0164
# Epoch 80/80
# 95/95 [==============================] - 0s 281us/sample - loss: 0.0130 - val_loss: 0.0162

# %%
# Plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# "Wrong" forecast using true targets

validation_target = Y[-N//2:]
validation_predictions = []

# index of first validation input
i = -N//2

while len(validation_predictions) < len(validation_target):
  p = model.predict(X[i].reshape(1, -1))[0,0] # 1x1 array -> scalar
  i += 1
  
  # update the predictions list
  validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %%
# Forecast future values (use only self-predictions for making future predictions)

validation_target = Y[-N//2:]
validation_predictions = []

# last train input
last_x = X[-N//2] # 1-D array of length T

while len(validation_predictions) < len(validation_target):
  p = model.predict(last_x.reshape(1, -1))[0,0] # 1x1 array -> scalar
  
  # update the predictions list
  validation_predictions.append(p)
  
  # make the new input
  last_x = np.roll(last_x, -1)
  last_x[-1] = p

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()
